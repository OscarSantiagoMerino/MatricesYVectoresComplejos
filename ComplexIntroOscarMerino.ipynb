# %% [markdown]
# # Complex numbers
#
# By: Luis Daniel Benavides N. (V1.0 26-01-2024)
#
# ## Tutorial Outline
#
# 1. Introduction to Complex Numbers
#     - Definition and notation
#     - Real and imaginary parts
#
# 2. Basic Operations with Complex Numbers
#     - Addition, subtraction, multiplication, division
#     - Conjugate and absolute value
#
# 3. Complex Numbers in Python
#     - Using Python's complex type
#     - Basic operations in Python
#
# 4. Polar Representation of Complex Numbers
#     - Polar representation
#     - Euler notation
#
# 6. Application: Fractals and Complex Numbers
#     - Introduction to fractals
#     - Generating a Mandelbrot set
#
# 7. Exercises for Students
#     - Practice problems on complex number operations
#     - Creating a Julia set fractal

# %% [markdown]
# ## Software Requirements
#
#     - numpy
#     - matplotlib
#     - ipywidgets

# %%
# %pip install numpy matplotlib ipywidgets
# Out:
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/66/a3/4139296b481ae7304a43581046b8f0a20da6a0dfe0ee47a044cade796603/numpy-2.2.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-2.2.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 165.2 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 196.9 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 238.1 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 216.3 kB/s eta 0:00:00
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/14/cf/e382598f98be11bf51dd0bc60eca44a517f6793e3dc8b9d53634a144620c/matplotlib-3.10.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting ipywidgets
#   Obtaining dependency information for ipywidgets from https://files.pythonhosted.org/packages/22/2d/9c0b76f2f9cc0ebede1b9371b6f317243028ed60b90705863d493bae622e/ipywidgets-8.1.5-py3-none-any.whl.metadata
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/a8/7e/cd93cab453720a5d6cb75588cc17dcdc08fc3484b9de98b885924ff61900/contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/86/33/281989403a57945c7871df144af3512ad3d1cd223e025b08b7f377847e6d/fonttools-4.55.7-cp311-cp311-win_amd64.whl.metadata
#   Downloading fonttools-4.55.7-cp311-cp311-win_amd64.whl.metadata (102 kB)
#      ---------------------------------------- 0.0/103.0 kB ? eta -:--:--
#      ----------------------- --------------- 61.4/103.0 kB 1.7 MB/s eta 0:00:01
#      ------------------------- ----------- 71.7/103.0 kB 991.0 kB/s eta 0:00:01
#      ------------------------------------ 103.0/103.0 kB 742.0 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/2d/27/bdf1c769c83f74d98cbc34483a972f221440703054894a37d174fba8aa68/kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\kimbo\appdata\roaming\python\python311\site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/3a/c6/fce9255272bcf0c39e15abd2f8fd8429a954cf344469eaceb9d0d1366913/pillow-11.1.0-cp311-cp311-win_amd64.whl.metadata
#   Downlo
MB/s eta 0:00:01
#    ----------- ---------------------------- 0.8/2.6 MB 3.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.9/2.6 MB 3.5 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.6 MB 3.3 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.6 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 3.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.6 MB 3.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 3.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/107.7 kB ? eta -:--:--
#    -------------------------------------- - 102.4/107.7 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 107.7/107.7 kB 1.5 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/2.3 MB 3.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.3 MB 3.1 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.3 MB 3.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.3 MB 3.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 3.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.3 MB 3.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.1/2.3 MB 3.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.3 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.4/2.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.5/2.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 3.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.0/2.3 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, pyparsing, pillow, numpy, kiwisolver, jupyterlab-widgets, fonttools, cycler, contourpy, matplotlib, ipywidgets
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.7 ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 kiwisolver-1.4.8 matplotlib-3.10.0 numpy-2.2.2 pillow-11.1.0 pyparsing-3.2.1 widgetsnbextension-4.0.13
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 1. Introduction to Complex Numbers
#     - Definition and notation
#     - Real and imaginary parts
#
# Complex numbers are an extension of the real numbers and are fundamental in advanced mathematics and engineering. They provide a solution to equations that have no real solutions, such as the square root of negative numbers.
#
# ## Definition
#
# A complex number is defined as a number of the form $ a + bi $, where:
#
# - $ a $ and $ b $ are real numbers,
# - $ i $ is the imaginary unit with the property $ i² = -1 $.
#
# The real part of the complex number is $ a $, and the imaginary part is $ b $.
#
# ## Imaginary Unit
#
# The imaginary unit $ i $ is defined by its property $ i² = -1 $. It allows the definition of complex numbers and facilitates the computation of the square root of negative numbers. For example, the square root of -1 is represented as $ i $, and the square root of -4 is $ 2i $.
#
# ## Complex Plane
#
# The complex plane is a two-dimensional plane where complex numbers are graphed. The horizontal axis represents the real part, and the vertical axis represents the imaginary part.
#
# ## Applications
#
# Complex numbers have applications in various fields, including engineering, physics, computer science, and more. They are especially useful in representing oscillations, waves, and other phenomena involving two-dimensional quantities.

# %% [markdown]
# # 2. Basic Operations with Complex Numbers
#
#     Addition, subtraction, multiplication, division
#     Conjugate and modulus value
#
# ## Algebraic Operations
#
# Complex numbers can be added, subtracted, multiplied, and divided:
#
# - **Addition**: $+: \mathbb{C} \times \mathbb{C}   \rightarrow \mathbb{C}:  (a_1+b_1i) + (a_2+b_2i) = (a_1+a_2) + (b_1+b_2)i$
# - **Subtraction**: $-: \mathbb{C} \times \mathbb{C}   \rightarrow \mathbb{C}: (a + bi) - (c + di) = (a - c) + (b - d)i $
# - **Multiplication**: $+: \mathbb{C} \times \mathbb{C}   \rightarrow \mathbb{C}: (a + bi)(c + di) = (ac - bd) + (ad + bc)i $
# - **Division**: $/: \mathbb{C} \times \mathbb{C}   \rightarrow \mathbb{C}: \frac{a + bi}{c + di} = \frac{(ac + bd) + (bc - ad)i}{c² + d²} $
#
# ## Complex Conjugate
#
# The complex conjugate of a complex number \( a + bi \) is \( a - bi \). It is obtained by changing the sign of the imaginary part. This concept is particularly useful in division and in finding the magnitude of complex numbers.
#
# $$ \text{ }^{-} : \mathbb{C} \rightarrow \mathbb{C} : \bar c = \overline {a + bi} = a -bi $$
#
# ## Magnitude (Modulus)
#
# The magnitude (or modulus) of a complex number \( a + bi \) is given by \( \sqrt{a² + b²} \). It represents the distance of the complex number from the origin in the complex plane.
#
# $$| \text{ }| : \mathbb{C} \rightarrow \mathbb{R} : |c| = |a + bi| = + \sqrt{a^2+b^2}$$

# %% [markdown]
# # 3. Complex Numbers in Python
#     - Using Python's complex type
#     - Basic operations in Python

# %%
# Example: Complex number operations in Python

# Creating complex numbers
z1 = complex(2, 3)  # 2 + 3j
z2 = complex(1, -1) # 1 - 1j
z3 = 2 + 2j

# Basic operations
print("Addition:", z1 + z2)
print("Subtraction:", z1 - z2)
print("Multiplication:", z1 * z2)
print("Division:", z1 / z2)

# Conjugate and absolute value
print("Conjugate of z1:", z1.conjugate())
print("Absolute value of z1:", abs(z1))
print("Absolute value of z1:", abs(z2))
print("Absolute value of z1:", abs(z3))
# Out:
# Addition: (3+2j)
# Subtraction: (1+4j)
# Multiplication: (5+1j)
# Division: (-0.5+2.5j)
# Conjugate of z1: (2-3j)
# Absolute value of z1: 3.605551275463989
# Absolute value of z1: 1.4142135623730951
# Absolute value of z1: 2.8284271247461903

# %% [markdown]
# # 4. Polar Representation of Complex Numbers
#
# In addition to the rectangular form (a + bi), complex numbers can also be represented in polar form. The polar form of a complex number expresses it in terms of a magnitude (r) and an angle (θ), and is written as `r(cos θ + i sin θ)` or `r∠θ`. This form is particularly useful in quantum computing, signal processing, and other fields where phase and amplitude are important.
#
# ## Key Concepts
# - **Magnitude (r)**: The distance of the complex number from the origin in the complex plane, calculated as `sqrt(a^2 + b^2)`.
# - **Angle (θ)**: The counterclockwise angle measured from the positive x-axis to the line segment that joins the point to the origin, often given in radians.
# - **Euler's Formula**: `e^(iθ) = cos θ + i sin θ`, which allows the polar form to be written as `r * e^(iθ)`.
#
# ## Converting between Rectangular and Polar Forms
# - To convert from rectangular to polar form, use `r = sqrt(a^2 + b^2)` and `θ = atan2(b, a)`.
# - To convert from polar to rectangular form, use `a = r * cos(θ)` and `b = r * sin(θ)`.
#
# ## Python Implementation
# Use Python's `cmath` module for working with complex numbers in polar form.

# %%
import cmath

# Example: Converting a complex number to its polar form and back

# Define a complex number in rectangular form
z = complex(3, 4)

# Convert to polar form
r, theta = cmath.polar(z)
print(f"Polar form: Magnitude = {r}, Angle = {theta} radians")

# Convert back to rectangular form
rectangular_form = cmath.rect(r, theta)
print(f"Rectangular form: {rectangular_form}")
# Out:
# Polar form: Magnitude = 5.0, Angle = 0.9272952180016122 radians
# Rectangular form: (3.0000000000000004+3.9999999999999996j)

# %% [markdown]
# ## An interactive tool for polar and cartesian conversion

# %%
import cmath
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

def convert_and_plot(real=0, imaginary=0, magnitude=0, angle=0, convert_to='polar'):
    if convert_to == 'polar':
        z = complex(real, imaginary)
        r, theta = cmath.polar(z)
        display_text = f"Cartesian: ({real}, {imaginary}) -> Polar: (r={r:.2f}, θ={np.degrees(theta):.2f}°)"
    else:
        z = cmath.rect(magnitude, np.radians(angle))
        display_text = f"Polar: (r={magnitude}, θ={angle}°) -> Cartesian: ({z.real:.2f}, {z.imag:.2f})"

    fig, ax = plt.subplots()
    ax.plot([0, z.real], [0, z.imag], 'ro-')
    ax.set_xlim(-5, 5)
    ax.set_ylim(-5, 5)
    ax.set_xlabel('Real')
    ax.set_ylabel('Imaginary')
    ax.axhline(0, color='black',linewidth=0.5)
    ax.axvline(0, color='black',linewidth=0.5)
    ax.grid(True)
    plt.title(display_text)
    plt.show()

style = {'description_width': 'initial'}
layout = widgets.Layout(width='400px')

# Creating interactive widgets
real_slider = widgets.FloatSlider(min=-5, max=5, step=0.1, value=0, description='Real Part:', style=style, layout=layout)
imaginary_slider = widgets.FloatSlider(min=-5, max=5, step=0.1, value=0, description='Imaginary Part:', style=style, layout=layout)
magnitude_slider = widgets.FloatSlider(min=0, max=5, step=0.1, value=1, description='Magnitude:', style=style, layout=layout)
angle_slider = widgets.FloatSlider(min=-180, max=180, step=1, value=0, description='Angle (degrees):', style=style, layout=layout)
convert_dropdown = widgets.Dropdown(options=['polar', 'cartesian'], value='polar', description='Convert to:', style=style, layout=layout)

# Interactive function

ui = widgets.VBox([widgets.HBox([real_slider, imaginary_slider]), 
                   widgets.HBox([magnitude_slider, angle_slider]),
                   convert_dropdown])
out = widgets.interactive_output(convert_and_plot, {'real': real_slider, 'imaginary': imaginary_slider, 
                                                    'magnitude': magnitude_slider, 'angle': angle_slider, 
                                                    'convert_to': convert_dropdown})

display(ui, out)
# Out:
# VBox(children=(HBox(children=(FloatSlider(value=0.0, description='Real Part:', layout=Layout(width='400px'), m…
# Output()

# %% [markdown]
# ## Euler's Notation for Complex Numbers
#
# Euler's formula is a fundamental equation in complex analysis and provides a deep connection between trigonometry and complex exponential functions. It states that for any real number `x`, the following identity holds:
#
# $$ e^{ix} = \cos(x) + i\sin(x) $$
#
# This equation is known as Euler's formula. In this formula, `e` is the base of the natural logarithm, `i` is the imaginary unit, and `cos` and `sin` are the trigonometric functions cosine and sine respectively. The formula is often used in the polar representation of complex numbers.
#
# ### Polar Representation Using Euler's Formula
#
# A complex number can be represented in polar coordinates as `r(cos θ + i sin θ)`. Using Euler's formula, this can be written in the more compact form:
#
# $$ z = r \cdot e^{iθ} $$
#
# where `r` is the magnitude (modulus) of the complex number, and `θ` is the angle formed with the positive real axis, often referred to as the argument of the complex number.
#
# ### Applications
#
# Euler's formula is widely used in various fields such as electrical engineering, quantum mechanics, and signal processing. It simplifies the analysis of waveforms, oscillations, and rotating systems.

# %%
import cmath
import numpy as np

# Example to demonstrate Euler's notation for complex numbers

# Define magnitude and angle
r = 2.0  # Magnitude
theta = np.pi / 4  # Angle in radians (45 degrees)

# Using Euler's formula: z = r * e^(iθ)
z = r * cmath.exp(complex(0, theta))

print(f"Complex number using Euler's notation: {z}")

# Verify by converting to Cartesian form
real_part = z.real
imaginary_part = z.imag
print(f"Cartesian form: {real_part} + {imaginary_part}i")
# Out:
# Complex number using Euler's notation: (1.4142135623730951+1.4142135623730951j)
# Cartesian form: 1.4142135623730951 + 1.4142135623730951i

# %% [markdown]
# # 5. Application: Fractals and Complex Numbers
#     - Introduction to fractals
#     - Generating a Mandelbrot set
#
# ## Understanding the Mandelbrot Set
#
# The Mandelbrot Set is a fascinating and complex structure in the field of fractal geometry, discovered by mathematician Benoit Mandelbrot in 1980. It's a set of complex numbers that forms an intricate and infinitely detailed boundary when plotted in the complex plane.
#
# ### What is the Mandelbrot Set?
# The Mandelbrot Set is defined as the set of complex numbers `c` for which the function `f(z) = z^2 + c` does not diverge when iterated from `z = 0`. In simpler terms, if repeatedly squaring the number and adding `c` never makes the value go to infinity, that number is part of the Mandelbrot Set.
#
# ### Key Concepts:
# - **Iteration**: Starting with `z = 0`, we repeatedly apply the function `f(z) = z^2 + c`. The behavior of this sequence determines if `c` is in the Mandelbrot Set.
# - **Boundedness**: If the sequence remains bounded (doesn't go to infinity), then `c` is in the Mandelbrot Set.
# - **Escape Time Algorithm**: To visualize the set, we use an algorithm that assigns a color based on how quickly the values reach a certain threshold when iterated. Points inside the set typically remain black.
#
# ### Properties of the Mandelbrot Set:
# - **Self-Similarity**: The set is fractal, meaning it contains smaller copies of itself.
# - **Complex Boundary**: The boundary of the Mandelbrot Set is infinitely complex. Zooming into the boundary reveals more detail.
# - **Area**: While the exact area of the Mandelbrot Set is unknown, it is finite.
# - **Connectedness**: Despite its complexity, the set is mathematically proven to be a connected set.
#
# ### Plotting the Mandelbrot Set:
# To visualize the set, we iterate over a grid of complex numbers and use the escape time algorithm to color each point. Points that remain bounded (do not escape) after a set number of iterations are considered part of the Mandelbrot Set and are usually colored black.
#
# The beauty of the Mandelbrot Set lies not just in its visual complexity, but also in the way it bridges mathematics, art, and computer science. It serves as a powerful example of how simple rules can lead to incredibly intricate structures.

# %%
# Example: Generating a Mandelbrot set

import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = 0
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

# Create a grid of complex numbers
pixels = 800
max_iter = 30
x = np.linspace(-2, 1, pixels)
y = np.linspace(-1.5, 1.5, pixels)
xx, yy = np.meshgrid(x, y)
c = xx + yy*1j

# Compute Mandelbrot set
mandelbrot_set = np.array([mandelbrot(ci, max_iter) for ci in c.ravel()]).reshape(c.shape)

# Plot
plt.imshow(mandelbrot_set, extent=[-2, 1, -1.5, 1.5])
plt.colorbar()
plt.title("Mandelbrot Set")
plt.show()

# %% [markdown]
# # 6. Exercises for Students
#     - Practice problems on complex number operations
#     - Creating a Julia set fractal

# %% [markdown]
# ## Exercise 1: Basic Complex Number Operations
# 1. Manually calculate and then verify using Python the result of `(3 + 4j) + (1 - 2j)`, `(5 + 6j) * (7 - 8j)`, and `(2 - 3j) / (1 + 4j)`.
# 2. Find the conjugate and modulus of `(3 - 4j)`.
#
# ## Exercise 2: Visualizing Complex Operations
# 1. Write a Python function to plot a complex number on the complex plane. Use it to plot `(3 + 4j)` and its conjugate.
# 2. Extend the function to show addition and multiplication of two complex numbers graphically.
#
# ## Exercise 3: Exploring the Mandelbrot Set
# 1. Modify the provided Mandelbrot set code to change its zoom level and center point. Observe how the fractal pattern changes.
# 2. Experiment with different values of `max_iter` and observe the effect on the fractal's detail and computation time.
#
# ## Exercise 4: Creating a Julia Set
# 1. Implement a Julia set generator. Use a constant like `-0.4 + 0.6j` for the iteration `z = z*z + constant`.
# 2. Explore how changing the constant changes the pattern of the Julia set.
#
# ## Exercise 5: Complex Number Properties
# 1. Prove that the absolute value of a product of two complex numbers is the product of their absolute values.
# 2. Show that the conjugate of a sum of two complex numbers is the sum of their conjugates.

# %% [markdown]
# # Respuestas
# ### Ejercicio 1.1
# Manually calculate and then verify using Python the result of `(3 + 4j) + (1 - 2j)`, `(5 + 6j) * (7 - 8j)`, and `(2 - 3j) / (1 + 4j)`.

# %% [markdown]
# ### Suma
# $$(3 + 4j) + (1 - 2j) = (3 + 1) + (4j - 2j) = 4 + 2j$$

# %% [markdown]
# ### Multiplicacion
#
# $$(5 + 6j) \cdot (7 - 8j) = 5(7) + 5(-8j) + 6j(7) + 6j(-8j)$$
# $$= 35 - 40j + 42j - 48j^2$$
# $$j^2 = -1$$
# $$35 - 40j + 42j + 48 = 83 + 2j$$

# %% [markdown]
# ### Division
#
# $$\frac{2-3j}{1+4j}\cdot \frac{1-4j}{1-4j}=\frac{(2-3j)(1-4j)}{(1+4j)(1-4j)}$$
#
# El denominador es:
#
# $$(1 + 4j)(1 - 4j) = 1^2 - (4j)^2 = 1 - (-16) = 1 + 16 = 17$$
#
# El numerador es:
#
# $$(2 - 3j)(1 - 4j) = 2(1) + 2(-4j) - 3j(1) - 3j(-4j)$$
#
# $$= 2 - 8j - 3j + 12j^2 = 2 - 8j - 3j - 12 = -10 - 11j$$
#
# y la divicion seria:
#
# $$\frac{-10-11j}{17}=\frac{-10}{17}-\frac{11}{17}j$$

# %%
def complxsuma (a,b):
    real = (a[0]+b[0])
    imaginario = (a[1]+b[1])
    return (f"el resultado de la suma de los numeros complejos es :{real},{imaginario}i")
def complxproducto (a,b):
    real = (a[0]*b[0]-a[1]*b[1])
    imaginario = (a[0]*b[1]+b[0]*a[1])
    return (f"el resultado del producto de los numeros complejos es :{real},{imaginario}i")
def complxdivision (a,b):
    if b == (0,0):
        return ("no se puede hacer")
    else:
        divisor= (b[0]**2)+(b[1]**2)
        real = (a[0]*b[0]+a[1]*b[1])/divisor
        imaginario = (b[0]*a[1]-a[0]*b[1])/divisor
    return (f"el resultado de la division de los numeros complejos es :{real},{imaginario}i")

print(complxsuma((3,4),(1,-2)))
z1 = complex(3,4)  
z2 = complex(1,-2) 
print("Addition:", z1 + z2)

print(complxproducto((5,6),(7,-8)))
z3 = complex(5,6)  
z4 = complex(7,-8) 
print("Multiplication:", z3 * z4)

print(complxdivision((2,-3),(1,4)))
z5 = complex(2,-3)  
z6 = complex(1,4) 
print("Division:", z5 / z6)
# Out:
# el resultado de la suma de los numeros complejos es :4,2i
# Addition: (4+2j)
# el resultado del producto de los numeros complejos es :83,2i
# Multiplication: (83+2j)
# el resultado de la division de los numeros complejos es :-0.5882352941176471,-0.6470588235294118i
# Division: (-0.5882352941176471-0.6470588235294118j)

# %% [markdown]
# ### Ejercicio 1.2
# Find the conjugate and modulus of `(3 - 4j)`.

# %%
def complxconjugado (a):
    real= a[0]
    imaginario = -a[1]
    return (f"el resultado del conjugado de tu numero complejo es {real},{imaginario}i")
def complxmodulo (a):
    if a == (0,0):
        return ("no se puede hacer")
    else:
        elevados = (a[0]**2+a[1]**2)
        raiz = elevados**0.5
        return (f"el resultado del modulo de tu numero complejo es {raiz}")

print(complxconjugado((3,-4)))
print(complxmodulo((3,-4)))
z1 = complex(3,-4)
print("Conjugate of z1:", z1.conjugate())
print("Absolute value of z1:", abs(z1))
# Out:
# el resultado del conjugado de tu numero complejo es 3,4i
# el resultado del modulo de tu numero complejo es 5.0
# Conjugate of z1: (3+4j)
# Absolute value of z1: 5.0

# %% [markdown]
# ### Ejercicio 2.1
# Write a Python function to plot a complex number on the complex plane. Use it to plot `(3 + 4j)` and its conjugate.

# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

def convert_and_plot(real=3, imaginary=4):
    conjugado = -imaginary
    y = complex(real, conjugado)
    z = complex(real, imaginary)
    fig, ax = plt.subplots()
    ax.plot([0, z.real], [0, z.imag])
    ax.plot([0, y.real], [0, y.imag])
    ax.set_xlim(-20, 20)
    ax.set_ylim(-20, 20)
    ax.set_xlabel('Real')
    ax.set_ylabel('Imaginary')
    ax.axhline(0, color='black',linewidth=0.5)
    ax.axvline(0, color='black',linewidth=0.5)
    ax.grid(True)
    plt.show()

style = {'description_width': 'initial'}
layout = widgets.Layout(width='400px')

# Creating interactive widgets
real_slider = widgets.FloatSlider(min=-20, max=20, step=1, value=3, description='Real Part:', style=style, layout=layout)
imaginary_slider = widgets.FloatSlider(min=-20, max=20, step=1, value=4, description='Imaginary Part:', style=style, layout=layout)

# Interactive function

ui = widgets.VBox([widgets.HBox([real_slider, imaginary_slider])])

out = widgets.interactive_output(convert_and_plot, {'real': real_slider, 'imaginary': imaginary_slider})

display(ui, out)
# Out:
# VBox(children=(HBox(children=(FloatSlider(value=3.0, description='Real Part:', layout=Layout(width='400px'), m…
# Output()

# %% [markdown]
# ### Ejercicio 2.2
# Extend the function to show addition and multiplication of two complex numbers graphically.

# %%
import cmath
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

def convert_and_plot(real=0, imaginary=0, real1=0, imaginary1=0, convert_to='suma'):
    if convert_to == 'suma':
        z = complex(real, imaginary)
        y = complex(real1,imaginary1)
        k = z+y
    else:
        z = complex(real, imaginary)
        y = complex(real1,imaginary1)
        k = z*y
        
    fig, ax = plt.subplots()
    ax.plot([0, k.real], [0, k.imag])
    ax.set_xlim(-20, 20)
    ax.set_ylim(-20, 20)
    ax.set_xlabel('Real')
    ax.set_ylabel('Imaginary')
    ax.axhline(0, color='black',linewidth=0.5)
    ax.axvline(0, color='black',linewidth=0.5)
    ax.grid(True)
    plt.show()

style = {'description_width': 'initial'}
layout = widgets.Layout(width='400px')

# Creating interactive widgets
real_slider = widgets.FloatSlider(min=-8, max=8, step=1, value=0, description='Real Part1:', style=style, layout=layout)
real_slider1 = widgets.FloatSlider(min=-8, max=8, step=1, value=0, description='Real Part2:', style=style, layout=layout)
imaginary_slider = widgets.FloatSlider(min=-8, max=8, step=1, value=0, description='Imaginary Part1:', style=style, layout=layout)
imaginary_slider1 = widgets.FloatSlider(min=-8, max=8, step=1, value=0, description='Imaginary Part2:', style=style, layout=layout)
convert_dropdown = widgets.Dropdown(options=['suma', 'producto'], value='suma', description='Convert to:', style=style, layout=layout)
# Interactive function

ui = widgets.VBox([widgets.HBox([real_slider, imaginary_slider,real_slider1,imaginary_slider1]),convert_dropdown])
out = widgets.interactive_output(convert_and_plot, {'real': real_slider, 'imaginary': imaginary_slider,'real1': real_slider1, 'imaginary1': imaginary_slider1,'convert_to': convert_dropdown})

display(ui, out)
# Out:
# VBox(children=(HBox(children=(FloatSlider(value=0.0, description='Real Part1:', layout=Layout(width='400px'), …
# Output()

# %% [markdown]
# ### Ejercicio 3.1
# Modify the provided Mandelbrot set code to change its zoom level and center point. Observe how the fractal pattern changes.
#
# R// al realizar el cambio del zoom y del centro se puede observar que la figura apartir de los cambios cambia su anchura y altura pero esto se debe simplemente al punto de vista que se le de a la figura ya que es la misma

# %%
# Example: Generating a Mandelbrot set

import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = 0
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

# Create a grid of complex numbers
pixels = 800
max_iter = 30
x = np.linspace(-1, 0.5, pixels)
y = np.linspace(-0.5, 2, pixels)
xx, yy = np.meshgrid(x, y)
c = xx + yy*1j

# Compute Mandelbrot set
mandelbrot_set = np.array([mandelbrot(ci, max_iter) for ci in c.ravel()]).reshape(c.shape)

# Plot
plt.imshow(mandelbrot_set, extent=[-1, 1, -1, 1])
plt.colorbar()
plt.title("Mandelbrot Set")
plt.show()

# %% [markdown]
# ### Ejercicio 3.2
# Experiment with different values of `max_iter` and observe the effect on the fractal's detail and computation time.
#
# R// Al realizar el cambio con diferentes max_iter al cambiar el numero de iteraciones del fractal este se hace mas compacto mientras mas iteraciones osea se hace mas lizo, pero cuando hay menos iteraciones se observa mas como un fractal lleno de canales.

# %%
# Example: Generating a Mandelbrot set

import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = 0
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

# Create a grid of complex numbers
pixels = 800
max_iter = 400
x = np.linspace(-2, 1, pixels)
y = np.linspace(-1.5, 1.5, pixels)
xx, yy = np.meshgrid(x, y)
c = xx + yy*1j

# Compute Mandelbrot set
mandelbrot_set = np.array([mandelbrot(ci, max_iter) for ci in c.ravel()]).reshape(c.shape)

# Plot
plt.imshow(mandelbrot_set, extent=[-2, 1, -1.5, 1.5])
plt.colorbar()
plt.title("Mandelbrot Set")
plt.show()

# %% [markdown]
# ### Ejercicio 4.1
# Implement a Julia set generator. Use a constant like `-0.4 + 0.6j` for the iteration `z = z*z + constant`.

# %%
# Example: Generating a julia set

import numpy as np
import matplotlib.pyplot as plt

def julia(z, c, max_iter):
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

# Create a grid of complex numbers
c = -0.4 + 0.6j
pixels = 800
max_iter = 20
x = np.linspace(-3, 3, pixels)
y = np.linspace(-2, 2, pixels)
xx, yy = np.meshgrid(x, y)
z = xx + yy*1j

# Compute julia set
julia_set = np.array([julia(zi,c, max_iter) for zi in z.ravel()]).reshape(z.shape)

# Plot
plt.imshow(julia_set, extent=[-3, 3, -2, 2])
plt.colorbar()
plt.title("julia Set")
plt.show()

# %% [markdown]
# ### Ejercicio 4.2
#  Explore how changing the constant changes the pattern of the Julia set.
#
#  R// la forma en que yo explico que es lo que ocurre con julia set cuando se hacen los cambios en la constante es que la grafica empieza a hacer mitosis cuando los valores son muy grandes y se compactan cuando son muy pequeños

# %%
# Example: Generating a julia set

import numpy as np
import matplotlib.pyplot as plt

def julia(z, c, max_iter):
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

# Create a grid of complex numbers
c = 0.2 + 0.9j # pruebe con 0.1 
pixels = 800
max_iter = 20
x = np.linspace(-3, 3, pixels)
y = np.linspace(-2, 2, pixels)
xx, yy = np.meshgrid(x, y)
z = xx + yy*1j

# Compute julia set
julia_set = np.array([julia(zi,c, max_iter) for zi in z.ravel()]).reshape(z.shape)

# Plot
plt.imshow(julia_set, extent=[-3, 3, -2, 2])
plt.colorbar()
plt.title("julia Set")
plt.show()

# %% [markdown]
# ### Ejercicio 5.1
# Prove that the absolute value of a product of two complex numbers is the product of their absolute values.

# %% [markdown]
# ### Se demostrara lo siguiente:
#
# Si  c1 = a + bj  y  c2 = c + fj  son dos números complejos, entonces probaremos que:
#
# $$|c_1\cdot c_2|=|c_1|\cdot |c_2|$$
#
# ### Demostracion:
#
# En el libro se observa que el valor absoluto de un numero complejo  c = a + bj  es:
#
# $$|c|=\sqrt{a^2+b^2}$$
#
# sabemos que:
#
# $$c_1=a+bj,\quad c_2=c+fj$$
#
# El producto de  c1  y  c2  visto en clase es:
#
# $$c_1\cdot c_2=ac-bf+(af+bc)j$$
#
# Por lo que el valor absoluto de este producto es:
#
# $$|c_1\cdot c_2|=\sqrt{(ac-bf)^2+(af+bc)^2}$$
#
# Expandiendo :
#
# $$(ac-bf)^2+(af+bc)^2=a^2c^2-2acbf+b^2f^2+a^2f^2+2afbc+b^2c^2$$
#
# cancelando los 2acbf :
#
# $$ a^2c^2+b^2c^2+a^2f^2+b^2f^2$$
#
# Factorizando:
#
# $$(a^2+b^2)(c^2+f^2)$$
#
# Tomando la raiz cuadrada:
#
# $$|c_1\cdot c_2|=\sqrt{(a^2+b^2)(c^2+f^2)}$$
#
# y se sabe que el valor absoluto de los numeros complejos es:
#
# $$|c_1|=\sqrt{a^2+b^2},\quad |c_2|=\sqrt{c^2+f^2}$$
#
# se puede concluir igualando los 2 pasos anteriores:
#
# $$|c_1\cdot c_2|=|c_1|\cdot |c_2|$$

# %% [markdown]
# ### Ejercicio 5.2
# Show that the conjugate of a sum of two complex numbers is the sum of their conjugates.

# %% [markdown]
# ### Se va a demostrar lo siguiente:
#
# Si  c_1 = a + bj  y  c_2 = c + fj  son dos numeros complejos, entonces se llegara a que:
#
#
# $$\overline{c_1+c_2}=\overline{c_1}+\overline{c_2}$$
#
# ### Demostracion:
#
# Sabemos que el conjugado de un número complejo  c = a + bj  es:
#
# $$\overline{c}=a-bj$$
#
# sabemos que:
#
# $$c_1=a+bj,\quad c_2=c+fj$$
#
# La suma de  c1  y  c2  es:
#
# $$c_1+c_2=(a+bj)+(c+fj)$$
#
# Aplicando la suma de numeros complejos :
#
# $$c_1+c_2=(a+c)+(b+f)j$$
#
# definicion de el conjugado:
#
# $$\overline{c_1+c_2}=(a+c)-(b+f)j$$
#
# Ahora por definicion de conjugado para cada uno de los numeros complejos:
#
# $$\overline{c_1}=a-bj,\quad\overline{c_2}=c-fj$$
#
# Sumamos los numeros complejos con respecto a los conjugados:
#
# $$\overline{c_1}+\overline{c_2}=(a-bj)+(c-fj)$$
#
# Realizando la suma de numeros complejos:
#
# $$\overline{c_1}+\overline{c_2}=(a+c)-(b+f)j$$
#
# y con esto ultimo se demuestra que:
#
# $$\overline{c_1+c_2}=\overline{c_1}+\overline{c_2}$$
